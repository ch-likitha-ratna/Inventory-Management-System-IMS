# %% [markdown]
# # Generating Sales file

# %%
import json
import time

# %%
sales = {}

sales = json.dumps(sales)

fd = open("sales.json", 'w')
fd.write(sales)
fd.close()

# %%
# Loading Inventory and Converting it to Dictionary
fd = open('record.json','r')
t = fd.read()
fd.close()
dct = json.loads(t)

# Loading Sales and Converting it to Dictionary
fd = open("sales.json", 'r')
sl = fd.read()
fd.close()
sales = json.loads(sl)


# Displaying Menu
print("**********************************************")
for i in dct.keys():
  print(i, dct[i])

print("******************************************\n")

# Taking Input from User to Enter what he/she wants to purchase
ui_prod  = input("Enter the product_Id: ")
ui_quant = int(input("Enter the quantity: "))


if (ui_prod in dct.keys()):                                                     # Checking If product Exists or not
    if (int(dct[ui_prod]['Quantity'] )>= ui_quant):                                        # If I'm having enough Quantity
      print("Name:",dct[ui_prod]['name'])
      print("Price:",dct[ui_prod]['cost'])
      print("Quantity:", ui_quant)
      print("------------------------------")
      print("Billing Amount:", int(dct[ui_prod]['cost']) * ui_quant)

      dct[ui_prod]['qn'] =str(int( dct[ui_prod]['Quantity']) - ui_quant)                        # Updating Inventory

      sales[str(len(sales)+1)] = {'prod_id' : ui_prod,                          # Updating Transection
                                  "time_pr" :  time.ctime(), 
                                  'bill' : int(dct[ui_prod]['cost'] )* ui_quant, 
                                  'qn' : ui_quant, 
                                  'pr' : dct[ui_prod]['cost'], 
                                  'pr_name' : dct[ui_prod]['name']}


    else:                                                                       # If I'm not having enough Quantity
      print("Sorry, We are not having that much of quantity.")
      print("We're only having",dct[ui_prod]['Quantity'],"quantity.")
      print("Would you like to purchase or not (Y/N)")
      ch = str(input("Y/N"))

      if (ch == "Y"):                                                           # If user wants to purchase the quantitry we're having
        print("Name:",dct[ui_prod]['name'])
        print("Price:",dct[ui_prod]['cost'])
        print("Quantity:", dct[ui_prod]['Quantity'])
        print("------------------------------")
        print("Billing Amount:", int(dct[ui_prod]['cost'] )*int( dct[ui_prod]['Quantity']))

        dct[ui_prod]['Quantity'] = 0                                                  # Updating Inventory

        sales[str(len(sales)+1)] = {'prod_id' : ui_prod,                        # Updating Transection
                                    "time_pr" :  time.ctime(), 
                                    'bill' : int(dct[ui_prod]['cost']) *int( dct[ui_prod]['Quantity']), 
                                    'qn' : dct[ui_prod]['Quantity'], 
                                    'pr' : dct[ui_prod]['cost'], 
                                    'pr_name' : dct[ui_prod]['name']}

      else:                                                                     # If user press anything Except Y
        print("Thankyou!")

else:                                                                           # Product ID Doesn't exists
  print("------------------------------")
  print("Product doesn't exist!")
  print("Please enter a valid product id")
  print("------------------------------")



sl = json.dumps(sales)                                                          # Updating Sales File
fd = open('sales.json','w')
fd.write(sl)
fd.close()

print("------------------------------")
print("Data Updated in Sales File!")

js = json.dumps(dct)                                                            # Updating Inventory File
fd = open('record.json','w')
fd.write(js)
fd.close()

print("Data Updated in Inventory File!")
# Out:
# **********************************************
# 1001 {'name': 'DairyMilk Chocolate ', 'cost': '45', 'Quantity': '23', 'Weight': '50g', 'CompanyName': 'DairyMilk'}
# 1002 {'name': 'Kitkat Chocolate', 'cost': '70', 'Quantity': '25', 'Weight': '50g', 'CompanyName': 'KitKat'}
# 1003 {'name': 'Snickers Familypack', 'cost': '100', 'Quantity': '10', 'Weight': '150g', 'CompanyName': 'Snickers'}
# 1004 {'name': 'Lays', 'cost': '20', 'Quantity': '100', 'Weight': '50g', 'CompanyName': 'Lays'}
# 1005 {'name': 'Bingo chips', 'cost': '20', 'Quantity': '98', 'Weight': '45g', 'CompanyName': 'Bingo'}
# 1006 {'name': 'Honey', 'cost': '315', 'Quantity': '15', 'Weight': '1L', 'CompanyName': 'Dabur'}
# 1007 {'name': 'Hide N Seek', 'cost': '30', 'Quantity': '20', 'Weight': '120', 'CompanyName': 'Parle'}
# 1008 {'name': 'Dark Fantasy', 'cost': '240', 'Quantity': '10', 'Weight': '500g', 'CompanyName': 'SunFeast'}
# 1009 {'name': 'Meera Shampoo', 'cost': '80', 'Quantity': '20', 'Weight': '100ml', 'CompanyName': 'Meera'}
# 1010 {'name': 'Dove Hair Conditioner', 'cost': '230', 'Quantity': '20', 'Weight': '500ml', 'CompanyName': 'Dove'}
# 1011 {'name': 'Mysore Sandal Soap', 'cost': '220', 'Quantity': '20', 'Weight': '450g', 'CompanyName': 'Mysore sandal'}
# 1012 {'name': 'Santoor SandalWood Soap', 'cost': '270', 'Quantity': '20', 'Weight': '175g', 'CompanyName': 'Santoor'}
# 1013 {'name': 'Rice', 'cost': '50', 'Quantity': '30', 'Weight': '1Kg', 'CompanyName': 'Daawat'}
# 1014 {'name': 'Basmati Rice', 'cost': '90', 'Quantity': '15', 'Weight': '1Kg', 'CompanyName': 'Daawat'}
# 1015 {'name': 'Freedom Cooking Oil', 'cost': '160', 'Quantity': '20', 'Weight': '1L', 'CompanyName': 'Sunflower'}
# 1016 {'name': 'Priya Groundnut Oil', 'cost': '140', 'Quantity': '18', 'Weight': '1L', 'CompanyName': 'Priya'}
# 1017 {'name': 'Horlicks', 'cost': '380', 'Quantity': '20', 'Weight': '1kg', 'CompanyName': 'Horlicks'}
# 1018 {'name': 'Cadbury Chocolate Powder ', 'cost': '140', 'Quantity': '30', 'Weight': '200g', 'CompanyName': 'Cadbury'}
# 1019 {'name': 'Ferrero Roacher Chocolate', 'cost': '400', 'Quantity': 0, 'Weight': '150g', 'CompanyName': 'Ferrero Roacher'}
# 1020 {'name': 'Cadbury Celbrations Chocolate', 'cost': '460', 'Quantity': '10', 'Weight': '180g', 'CompanyName': 'Cadbury'}
# 1021 {'name': 'Red Bull Energy Drink', 'cost': '50', 'Quantity': '30', 'Weight': '70ml', 'CompanyName': 'Red Bull'}
# 1022 {'name': 'Pulpy Orange Drink', 'cost': '120', 'Quantity': '30', 'Weight': '250ml', 'CompanyName': 'Minute Maid'}
# 1023 {'name': 'Mixed Fruit Juice', 'cost': '220', 'Quantity': '20', 'Weight': '1L', 'CompanyName': 'B Natural'}
# 1024 {'name': 'Sprite Soft Drink', 'cost': '130', 'Quantity': '20', 'Weight': '250ml', 'CompanyName': 'Sprite'}
# 1025 {'name': 'Choco Pie', 'cost': '120', 'Quantity': '20', 'Weight': '100g', 'CompanyName': 'Lotte'}
# 1026 {'name': 'Oreo Biscuits', 'cost': '80', 'Quantity': '30', 'Weight': '300g', 'CompanyName': 'Cadbury'}
# 1027 {'name': 'Milk Bikies', 'cost': '40', 'Quantity': '30', 'Weight': '200g', 'CompanyName': 'Britania'}
# 1028 {'name': 'Unibic Cookies', 'cost': '25', 'Quantity': '30', 'Weight': '100g', 'CompanyName': 'Unibic'}
# 1029 {'name': 'Little Heart Biscuits', 'cost': '25', 'Quantity': '30', 'Weight': '100g', 'CompanyName': 'Britannia'}
# 1030 {'name': 'Popcorn', 'cost': '25', 'Quantity': '20', 'Weight': '100g', 'CompanyName': 'Act 2'}
# ******************************************
#
# Enter the product_Id: 1023
# Enter the quantity: 2
# Name: Mixed Fruit Juice
# Price: 220
# Quantity: 2
# ------------------------------
# Billing Amount: 440
# ------------------------------
# Data Updated in Sales File!
# Data Updated in Inventory File!

# %%
sales
# Out:
# {'1': {'prod_id': '1019',
#   'time_pr': 'Sat Sep 11 12:08:39 2021',
#   'bill': 0,
#   'qn': 0,
#   'pr': '400',
#   'pr_name': 'Ferrero Roacher Chocolate'},
#  '2': {'prod_id': '1023',
#   'time_pr': 'Sat Sep 11 12:09:46 2021',
#   'bill': 440,
#   'qn': 2,
#   'pr': '220',
#   'pr_name': 'Mixed Fruit Juice'}}

# %%
dct
# Out:
# {'1001': {'name': 'DairyMilk Chocolate ',
#   'cost': '45',
#   'Quantity': '23',
#   'Weight': '50g',
#   'CompanyName': 'DairyMilk'},
#  '1002': {'name': 'Kitkat Chocolate',
#   'cost': '70',
#   'Quantity': '25',
#   'Weight': '50g',
#   'CompanyName': 'KitKat'},
#  '1003': {'name': 'Snickers Familypack',
#   'cost': '100',
#   'Quantity': '10',
#   'Weight': '150g',
#   'CompanyName': 'Snickers'},
#  '1004': {'name': 'Lays',
#   'cost': '20',
#   'Quantity': '100',
#   'Weight': '50g',
#   'CompanyName': 'Lays'},
#  '1005': {'name': 'Bingo chips',
#   'cost': '20',
#   'Quantity': '98',
#   'Weight': '45g',
#   'CompanyName': 'Bingo'},
#  '1006': {'name': 'Honey',
#   'cost': '315',
#   'Quantity': '15',
#   'Weight': '1L',
#   'CompanyName': 'Dabur'},
#  '1007': {'name': 'Hide N Seek',
#   'cost': '30',
#   'Quantity': '20',
#   'Weight': '120',
#   'CompanyName': 'Parle'},
#  '1008': {'name': 'Dark Fantasy',
#   'cost': '240',
#   'Quantity': '10',
#   'Weight': '500g',
#   'CompanyName': 'SunFeast'},
#  '1009': {'name': 'Meera Shampoo',
#   'cost': '80',
#   'Quantity': '20',
#   'Weight': '100ml',
#   'CompanyName': 'Meera'},
#  '1010': {'name': 'Dove Hair Conditioner',
#   'cost': '230',
#   'Quantity': '20',
#   'Weight': '500ml',
#   'CompanyName': 'Dove'},
#  '1011': {'name': 'Mysore Sandal Soap',
#   'cost': '220',
#   'Quantity': '20',
#   'Weight': '450g',
#   'CompanyName': 'Mysore sandal'},
#  '1012': {'name': 'Santoor SandalWood Soap',
#   'cost': '270',
#   'Quantity': '20',
#   'Weight': '175g',
#   'CompanyName': 'Santoor'},
#  '1013': {'name': 'Rice',
#   'cost': '50',
#   'Quantity': '30',
#   'Weight': '1Kg',
#   'CompanyName': 'Daawat'},
#  '1014': {'name': 'Basmati Rice',
#   'cost': '90',
#   'Quantity': '15',
#   'Weight': '1Kg',
#   'CompanyName': 'Daawat'},
#  '1015': {'name': 'Freedom Cooking Oil',
#   'cost': '160',
#   'Quantity': '20',
#   'Weight': '1L',
#   'CompanyName': 'Sunflower'},
#  '1016': {'name': 'Priya Groundnut Oil',
#   'cost': '140',
#   'Quantity': '18',
#   'Weight': '1L',
#   'CompanyName': 'Priya'},
#  '1017': {'name': 'Horlicks',
#   'cost': '380',
#   'Quantity': '20',
#   'Weight': '1kg',
#   'CompanyName': 'Horlicks'},
#  '1018': {'name': 'Cadbury Chocolate Powder ',
#   'cost': '140',
#   'Quantity': '30',
#   'Weight': '200g',
#   'CompanyName': 'Cadbury'},
#  '1019': {'name': 'Ferrero Roacher Chocolate',
#   'cost': '400',
#   'Quantity': 0,
#   'Weight': '150g',
#   'CompanyName': 'Ferrero Roacher'},
#  '1020': {'name': 'Cadbury Celbrations Chocolate',
#   'cost': '460',
#   'Quantity': '10',
#   'Weight': '180g',
#   'CompanyName': 'Cadbury'},
#  '1021': {'name': 'Red Bull Energy Drink',
#   'cost': '50',
#   'Quantity': '30',
#   'Weight': '70ml',
#   'CompanyName': 'Red Bull'},
#  '1022': {'name': 'Pulpy Orange Drink',
#   'cost': '120',
#   'Quantity': '30',
#   'Weight': '250ml',
#   'CompanyName': 'Minute Maid'},
#  '1023': {'name': 'Mixed Fruit Juice',
#   'cost': '220',
#   'Quantity': '20',
#   'Weight': '1L',
#   'CompanyName': 'B Natural',
#   'qn': '18'},
#  '1024': {'name': 'Sprite Soft Drink',
#   'cost': '130',
#   'Quantity': '20',
#   'Weight': '250ml',
#   'CompanyName': 'Sprite'},
#  '1025': {'name': 'Choco Pie',
#   'cost': '120',
#   'Quantity': '20',
#   'Weight': '100g',
#   'CompanyName': 'Lotte'},
#  '1026': {'name': 'Oreo Biscuits',
#   'cost': '80',
#   'Quantity': '30',
#   'Weight': '300g',
#   'CompanyName': 'Cadbury'},
#  '1027': {'name': 'Milk Bikies',
#   'cost': '40',
#   'Quantity': '30',
#   'Weight': '200g',
#   'CompanyName': 'Britania'},
#  '1028': {'name': 'Unibic Cookies',
#   'cost': '25',
#   'Quantity': '30',
#   'Weight': '100g',
#   'CompanyName': 'Unibic'},
#  '1029': {'name': 'Little Heart Biscuits',
#   'cost': '25',
#   'Quantity': '30',
#   'Weight': '100g',
#   'CompanyName': 'Britannia'},
#  '1030': {'name': 'Popcorn',
#   'cost': '25',
#   'Quantity': '20',
#   'Weight': '100g',
#   'CompanyName': 'Act 2'}}
